# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import IPython
print(IPython.sys_info())
# Out:
# {'commit_hash': '8bda98619',
#  'commit_source': 'installation',
#  'default_encoding': 'cp1255',
#  'ipython_path': 'C:\\Users\\Gal\\anaconda3\\lib\\site-packages\\IPython',
#  'ipython_version': '7.12.0',
#  'os_name': 'nt',
#  'platform': 'Windows-10-10.0.18362-SP0',
#  'sys_executable': 'C:\\Users\\Gal\\anaconda3\\python.exe',
#  'sys_platform': 'win32',
#  'sys_version': '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit '
#                 '(AMD64)]'}

# %%
c.Completer.use_jedi = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a002ff478219> in <module>
# ----> 1 c.Completer.use_jedi = False
#
# NameError: name 'c' is not defined

# %%
beforeimage = mpimg.imread("Desktop/before.png")
afterimage = mpimg.imread("Desktop/after.png")

# %%
print(np.shape(beforeimage))
print(np.shape(afterimage))
# Out:
# (299, 431, 4)
# (299, 431, 4)

# %%
afterimage = np.delete(afterimage, 3, 2)

# %%
beforeimage = np.delete(beforeimage, 3, 2)

# %%
np.shape(beforeimage)
# Out:
# (299, 431, 3)

# %%
np.shape(afterimage)
# Out:
# (299, 431, 3)

# %% [markdown]
# Before Image

# %%
    plt.imshow(beforeimage)

# %% [markdown]
# After Image

# %%
plt.imshow(afterimage)

# %%
diff = np.abs(afterimage - beforeimage)

# %%
plt.imshow(diff)
