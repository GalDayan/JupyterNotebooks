# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
beforeimage = mpimg.imread("before.png")
afterimage = mpimg.imread("after.png")

# %%
print(np.shape(beforeimage))
print(np.shape(afterimage))
# Out:
# (299, 431, 4)
# (299, 431, 4)

# %%
afterimage = np.delete(afterimage, 3, 2)

# %%
beforeimage = np.delete(beforeimage, 3, 2)

# %%
np.shape(beforeimage)
# Out:
# (299, 431, 3)

# %%
np.shape(afterimage)
# Out:
# (299, 431, 3)

# %% [markdown]
# Before Image

# %%
    plt.imshow(beforeimage)

# %% [markdown]
# After Image

# %%
plt.imshow(afterimage)
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter: Data Science libraries notebook and jupyter are not installed in interpreter Python 3.7.7 64-bit.
# at b.startServer (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:92:270430)
# at processTicksAndRejections (internal/process/task_queues.js:85:5)
# at async b.createServer (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:92:269873)
# at async connect (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:92:397876)
# at async w.ensureConnectionAndNotebookImpl (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:16:556625)
# at async w.ensureConnectionAndNotebook (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:16:556303)
# at async w.clearResult (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:16:552346)
# at async w.reexecuteCell (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:16:540374)
# at async w.reexecuteCells (c:\Users\Gal\.vscode\extensions\ms-python.python-2020.5.78807\out\client\extension.js:16:537541)

# %%
diff = np.abs(afterimage - beforeimage)

# %%
plt.imshow(diff)
